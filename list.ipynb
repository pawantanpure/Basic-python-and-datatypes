# %%
l=[]
l
# Out:
# []

# %%
l=[]
l
# Out:
# []

# %%
print(l)
# Out:
# []

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
l1=[1,2,3,4,5]
l1
# Out:
# [1, 2, 3, 4, 5]

# %%
l2=['one','two','three','four','five']
l2
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
l3=[1,2,3,'one','two','three',1.5,2.5,3.5]
l3
# Out:
# [1, 2, 3, 'one', 'two', 'three', 1.5, 2.5, 3.5]

# %%
l3
# Out:
# [1, 2, 3, 'one', 'two', 'three', 1.5, 2.5, 3.5]

# %%
l3[0]
# Out:
# 1

# %%
l3[3]
# Out:
# 'one'

# %%
l3[2]
# Out:
# 3

# %%
l3[-1]
# Out:
# 3.5

# %%
l3[-6]
# Out:
# 'one'

# %%
l3
# Out:
# [1, 2, 3, 'one', 'two', 'three', 1.5, 2.5, 3.5]

# %%
l3[0][0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 l3[0][0]
#
# TypeError: 'int' object is not subscriptable

# %%
l3[-4]
# Out:
# 'three'

# %%
l5=['one','two','three','four','five','six','seven','eight','nine']
l5
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
l5[2:3]
# Out:
# ['three']

# %%
l5[:2]
# Out:
# ['one', 'two']

# %%
l5=['one','two','three','four','five','six','seven','eight','nine']
l5
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
l5[-3]
# Out:
# 'seven'

# %%
l5[3:2]
# Out:
# []

# %%
l5[:2]
# Out:
# ['one', 'two']

# %%
l5=['one','two','three','four','five','six','seven','eight','nine']
l5
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
l5
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
l5[-5]
# Out:
# 'five'

# %%
l5[-4]
# Out:
# 'six'

# %%
l5[:]
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
l5.append('ten')
l5
# Out:
# ['one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten',
#  'ten',
#  'ten',
#  'ten',
#  'ten']

# %%
l5.append('six')

# %%
l5
# Out:
# ['one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten',
#  'ten',
#  'ten',
#  'ten',
#  'ten',
#  'six',
#  'six',
#  'six',
#  'six']

# %%
l5.insert(0,'one')

# %%
l5
# Out:
# ['one',
#  'one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten',
#  'ten',
#  'ten',
#  'ten',
#  'ten',
#  'six',
#  'six',
#  'six',
#  'six']

# %%
l5.insert(1,'two')

# %%
l5
# Out:
# ['one',
#  'two',
#  'one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten',
#  'ten',
#  'ten',
#  'ten',
#  'ten',
#  'six',
#  'six',
#  'six',
#  'six']

# %%
l6=[1,2,3,4,5]
l6
# Out:
# [1, 2, 3, 4, 5]

# %%
l6.insert(1,4)

# %%
l6
# Out:
# [1, 4, 2, 3, 4, 5]

# %%
l6.insert(1,10)
l6
# Out:
# [1, 10, 10, 4, 2, 3, 4, 5]

# %%
l6.insert(1,11)
l6
# Out:
# [1, 11, 10, 10, 4, 2, 3, 4, 5]

# %%
l6.insert(5,15)

# %%
l6
# Out:
# [1, 11, 10, 10, 4, 15, 2, 3, 4, 5]

# %%
l6.insert(2,16)
l6
# Out:
# [1, 11, 16, 10, 10, 4, 15, 2, 3, 4, 5]

# %%
l6.insert()
l6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 l6.insert()
#       2 l6
#
# TypeError: insert expected 2 arguments, got 0

# %%
l5
# Out:
# ['one',
#  'two',
#  'one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten',
#  'ten',
#  'ten',
#  'ten',
#  'ten',
#  'six',
#  'six',
#  'six',
#  'six']

# %%
l5=['one','two','three','four','five','six','seven','eight']
l5
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
l5.remove('two')
l5
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 l5.remove('two')
#       2 l5
#
# ValueError: list.remove(x): x not in list

# %%
l5.remove('two')
l5
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 l5.remove('two')
#       2 l5
#
# ValueError: list.remove(x): x not in list

# %%
l5
# Out:
# ['one', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
l5.remove('eight')
l5
# Out:
# ['three', 'four', 'five', 'seven']

# %%
l5
# Out:
# ['three', 'four', 'five', 'seven']

# %%
l5=['one','two','three','four','five','six','seven']
l5
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven']

# %%
l5.remove('two')
l5
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 l5.remove('two')
#       2 l5
#
# ValueError: list.remove(x): x not in list

# %%
l5
# Out:
# ['one', 'three', 'four', 'five', 'six', 'seven']

# %%
l5.pop(2)
# Out:
# 'four'

# %%
l5.pop(4)
# Out:
# 'seven'

# %%
l5.pop(3)
# Out:
# 'six'

# %%
l5.clear()
l5
# Out:
# []

# %%
l5=['one','two','three','four','five','six','seven']
l5
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven']

# %%
l6=['one','two','three','four','four','six','six']
l6
# Out:
# ['one', 'two', 'three', 'four', 'four', 'six', 'six']

# %%
l5=l6.copy()
l5
# Out:
# ['one', 'two', 'three', 'four', 'four', 'six', 'six']

# %%
l5=['one','two','three','four','five','six','seven']

l6=['one','two','two','two','five','six','seven']
l7=l5+l6
l7
# Out:
# ['one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'one',
#  'two',
#  'two',
#  'two',
#  'five',
#  'six',
#  'seven']

# %%
l5=['one','two','three','four','five','six','seven']
l5
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven']

# %%
'one' in l5
# Out:
# True

# %%
'four'in l5
# Out:
# True

# %%
'fifty' in l5
# Out:
# False

# %%
l5
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven']

# %%
l5.reverse()
l5
# Out:
# ['seven', 'six', 'five', 'four', 'three', 'two', 'one']

# %%
l6
# Out:
# ['one', 'two', 'two', 'two', 'five', 'six', 'seven']

# %%
l6.reverse()
l6
# Out:
# ['seven', 'six', 'five', 'two', 'two', 'two', 'one']

# %%
l1=[1,2,6,3,4,7,9,0]
l1
# Out:
# [1, 2, 6, 3, 4, 7, 9, 0]

# %%
l1.sort()
l1
# Out:
# [0, 1, 2, 3, 4, 6, 7, 9]

# %%
l2=[1,2,6,3,4,7,9,0]
l2
# Out:
# [1, 2, 6, 3, 4, 7, 9, 0]

# %%
l2.sort()
l2
# Out:
# [0, 1, 2, 3, 4, 6, 7, 9]

# %%
l2.sort(reverse=True)
l2
# Out:
# [9, 7, 6, 4, 3, 2, 1, 0]

# %%
l2
# Out:
# [9, 7, 6, 4, 3, 2, 1, 0]

# %%
for i in l2:
    print(i)
# Out:
# 9
# 7
# 6
# 4
# 3
# 2
# 1
# 0

# %%
l1
# Out:
# [0, 1, 2, 3, 4, 6, 7, 9]

# %%
for i in l1:
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 6
# 7
# 9

# %%
l1
# Out:
# [0, 1, 2, 3, 4, 6, 7, 9]

# %%
all(l1)
# Out:
# False

# %%
any(l1)
# Out:
# True

# %%
all(l2)
# Out:
# False

# %%
any(l2)
# Out:
# True
