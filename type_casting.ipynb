# %% [markdown]
# #Test Case 1

# %%
int(4)
# Out:
# 4

# %%
int(3.4)
# Out:
# 3

# %%
int(2.5)
# Out:
# 2

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int(True+False)
# Out:
# 1

# %%
int(False+False)
# Out:
# 0

# %%
int(True+True)
# Out:
# 2

# %%
int(2+6j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 int(2+6j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('12')
# Out:
# 12

# %%
int('2.2')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 int('2.2')
#
# ValueError: invalid literal for int() with base 10: '2.2'

# %%
int('16')
# Out:
# 16

# %%
int('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %%
#Test Case 2

# %%
float(3)
# Out:
# 3.0

# %%
float(34)
# Out:
# 34.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float(3+4j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 float(3+4j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float('34')
# Out:
# 34.0

# %%
float('nine')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 float('nine')
#
# ValueError: could not convert string to float: 'nine'

# %%
#Test Case 3
#change to all data type to bool

# %%
bool(34)
# Out:
# True

# %%
bool(34.0)
# Out:
# True

# %%
bool(True)
# Out:
# True

# %%
bool(False)
# Out:
# False

# %%
bool(34+3)
# Out:
# True

# %%
bool(34+3j)
# Out:
# True

# %%
bool('pawan')
# Out:
# True

# %%
bool(none)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 bool(none)
#
# NameError: name 'none' is not defined

# %%
bool(None)
# Out:
# False

# %%
complex(23)
# Out:
# (23+0j)

# %%
complex(23.0)
# Out:
# (23+0j)

# %%
complex(10,30)
# Out:
# (10+30j)

# %%
comlex(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 comlex(10,20,30)
#
# NameError: name 'comlex' is not defined

# %%
complex(2.0,3)
# Out:
# (2+3j)

# %%
complex(2.0+1.0)
# Out:
# (3+0j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex('45')
# Out:
# (45+0j)

# %%
complex('pawan')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 complex('pawan')
#
# ValueError: complex() arg is a malformed string

# %%
#Test Case 4
#other data type to string

# %%
str(20)
# Out:
# '20'

# %%
str(20.0)
# Out:
# '20.0'

# %%
str(True)
# Out:
# 'True'

# %%
str(False)
# Out:
# 'False'

# %%
str(1+3j)
# Out:
# '(1+3j)'

# %% [markdown]
# #operators
# #Arithmetic operators

# %%
x1,y1 = 20,5

# %%
x1+y1
# Out:
# 25

# %%
x1-y1
# Out:
# 15

# %%
x1*y1
# Out:
# 100

# %%
x1/y1
# Out:
# 4.0

# %%
x1//y1
# Out:
# 4

# %%
x1**y1
# Out:
# 3200000

# %%
x1%y1
# Out:
# 0

# %%
#assignment operators

# %%
x=4

# %%
x=x+2
x
# Out:
# 6

# %%
x+=2
x
# Out:
# 8

# %%
x-=2
x
# Out:
# 4

# %%
x-=3
x
# Out:
# -1

# %%
x*=2
x
# Out:
# 4

# %%
x/=2
x
# Out:
# -0.25

# %% [markdown]
# #Relational Operators

# %%
a=4
b=2

# %%
a>b
# Out:
# True

# %%
a<b
# Out:
# False

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
a=4
b=4

# %%
a<b
# Out:
# False

# %%
a>b
# Out:
# False

# %%
a==b
# Out:
# True

# %% [markdown]
# #LOgical OPerators

# %%
a=5
b=4

# %%
a<8 and b<5
# Out:
# True

# %%
a>3 and b<7
# Out:
# True

# %%
a<8 and b<2
# Out:
# False

# %%
x=False
x
# Out:
# False

# %%
x
# Out:
# False
