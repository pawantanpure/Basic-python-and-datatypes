# %%
#Forward indexing

# %%
s='welcome'
s
# Out:
# 'welcome'

# %%
s[3]
# Out:
# 'c'

# %%
s[4]
# Out:
# 'o'

# %%
s[6]
# Out:
# 'e'

# %%
s='welcome'
s
# Out:
# 'welcome'

# %%
s[3]
# Out:
# 'c'

# %%
s[2]
# Out:
# 'l'

# %%
s[6]
# Out:
# 'e'

# %%
s[5]
# Out:
# 'm'

# %%
#Forward Silicing

# %%
s='phone'
s
# Out:
# 'phone'

# %%
s[2:4]
# Out:
# 'on'

# %%
s[1:4]
# Out:
# 'hon'

# %%
s[3:6]
# Out:
# 'ne'

# %%
s[1:6]
# Out:
# 'hone'

# %%
#Backward Slicing

# %%
s='pawantanpure'
s
# Out:
# 'pawantanpure'

# %%
s[-2]
# Out:
# 'r'

# %%
s[-5]
# Out:
# 'n'

# %%
s[-3]
# Out:
# 'u'

# %%
s[-3:]
# Out:
# 'ure'

# %%
s[-4:]
# Out:
# 'pure'

# %%
s[-5:]
# Out:
# 'npure'

# %%
s[-7]
# Out:
# 't'
